# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Importing-modules" data-toc-modified-id="Importing-modules-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Importing modules</a></span></li><li><span><a href="#Setting-up-variables" data-toc-modified-id="Setting-up-variables-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Setting up variables</a></span></li><li><span><a href="#Setting-up-functions" data-toc-modified-id="Setting-up-functions-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Setting up functions</a></span></li><li><span><a href="#Trying-with-iterations" data-toc-modified-id="Trying-with-iterations-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Trying with iterations</a></span></li><li><span><a href="#Try-some-plots" data-toc-modified-id="Try-some-plots-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Try some plots</a></span><ul class="toc-item"><li><span><a href="#Test-with-k-(n_results)" data-toc-modified-id="Test-with-k-(n_results)-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Test with k (n_results)</a></span><ul class="toc-item"><li><span><a href="#Test-with-exponential-distribution" data-toc-modified-id="Test-with-exponential-distribution-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Test with exponential distribution</a></span><ul class="toc-item"><li><span><a href="#Task-1" data-toc-modified-id="Task-1-5.1.1.1"><span class="toc-item-num">5.1.1.1&nbsp;&nbsp;</span>Task 1</a></span></li><li><span><a href="#Task-2" data-toc-modified-id="Task-2-5.1.1.2"><span class="toc-item-num">5.1.1.2&nbsp;&nbsp;</span>Task 2</a></span></li><li><span><a href="#together" data-toc-modified-id="together-5.1.1.3"><span class="toc-item-num">5.1.1.3&nbsp;&nbsp;</span>together</a></span></li></ul></li></ul></li><li><span><a href="#test-m:-n_documents" data-toc-modified-id="test-m:-n_documents-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>test m: n_documents</a></span><ul class="toc-item"><li><span><a href="#task1" data-toc-modified-id="task1-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>task1</a></span></li><li><span><a href="#Task-2" data-toc-modified-id="Task-2-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Task 2</a></span></li><li><span><a href="#together" data-toc-modified-id="together-5.2.3"><span class="toc-item-num">5.2.3&nbsp;&nbsp;</span>together</a></span></li></ul></li><li><span><a href="#p:-length-of-list" data-toc-modified-id="p:-length-of-list-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>p: length of list</a></span><ul class="toc-item"><li><span><a href="#task1" data-toc-modified-id="task1-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>task1</a></span></li><li><span><a href="#delete-data-txt" data-toc-modified-id="delete-data-txt-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>delete data txt</a></span></li><li><span><a href="#task2" data-toc-modified-id="task2-5.3.3"><span class="toc-item-num">5.3.3&nbsp;&nbsp;</span>task2</a></span></li><li><span><a href="#together" data-toc-modified-id="together-5.3.4"><span class="toc-item-num">5.3.4&nbsp;&nbsp;</span>together</a></span></li><li><span><a href="#delete-data-txt" data-toc-modified-id="delete-data-txt-5.3.5"><span class="toc-item-num">5.3.5&nbsp;&nbsp;</span>delete data txt</a></span></li></ul></li><li><span><a href="#n:-n_query" data-toc-modified-id="n:-n_query-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>n: n_query</a></span><ul class="toc-item"><li><span><a href="#generate-txt" data-toc-modified-id="generate-txt-5.4.1"><span class="toc-item-num">5.4.1&nbsp;&nbsp;</span>generate txt</a></span></li><li><span><a href="#task-1" data-toc-modified-id="task-1-5.4.2"><span class="toc-item-num">5.4.2&nbsp;&nbsp;</span>task 1</a></span></li><li><span><a href="#task-2" data-toc-modified-id="task-2-5.4.3"><span class="toc-item-num">5.4.3&nbsp;&nbsp;</span>task 2</a></span></li><li><span><a href="#together" data-toc-modified-id="together-5.4.4"><span class="toc-item-num">5.4.4&nbsp;&nbsp;</span>together</a></span></li><li><span><a href="#delete-data-txt" data-toc-modified-id="delete-data-txt-5.4.5"><span class="toc-item-num">5.4.5&nbsp;&nbsp;</span>delete data txt</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# - sorry for a lot of code looks like shit :)

# %% [markdown]
# # Importing modules

# %%
import time
import os
import os.path
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from subprocess import call, run, check_output

import pandas
from pandas import DataFrame as df
import numpy

# %% [markdown]
# # Setting up variables

# %%
queries = [] # all the queries

for file in os.listdir("./data"):
    if file.endswith(".txt"):
        queries.append(file[:-4])
queries
# Out:
# ['a',
#  'ada',
#  'age',
#  'air',
#  'alan',
#  'algorithms',
#  'all',
#  'an',
#  'and',
#  'april',
#  'are',
#  'as',
#  'assassin',
#  'at',
#  'b',
#  'back',
#  'bag',
#  'banana',
#  'battle',
#  'be',
#  'beginner',
#  'bitcoin',
#  'boat',
#  'but',
#  'by',
#  'c',
#  'can',
#  'car',
#  'cat',
#  'chess',
#  'computer',
#  'concurrent',
#  'cryptocurrency',
#  'cryptography',
#  'dark',
#  'day',
#  'deep',
#  'do',
#  'dog',
#  'down',
#  'each',
#  'emoji',
#  'empires',
#  'fantasy',
#  'flight',
#  'for',
#  'fresh',
#  'from',
#  'fun',
#  'game',
#  'go',
#  'had',
#  'harmony',
#  'have',
#  'he',
#  'hello',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'is',
#  'it',
#  'kangaroo',
#  'league',
#  'left',
#  'legends',
#  'lovelace',
#  'melbourne',
#  'moron',
#  'mythology',
#  'no',
#  'not',
#  'of',
#  'omnipotent',
#  'omniscient',
#  'on',
#  'one',
#  'or',
#  'out',
#  'oxymoron',
#  'plane',
#  'player',
#  'power',
#  'program',
#  'putin',
# ...

# %%
# number of iterations
n_iter = 3

# k
# default n_result
n_results = 10

# +5 here because I want to explore when the n_results gets larger than
# n_documents, how does the program behave, default should be +2
exp_n_results = np.concatenate([[0], 
                                np.logspace(0, int(np.log2(1e+6)),
                                            base=2)], axis=0)
# 0, 2, 4, 8, 16... 131072

# m
lin_n_queries = np.arange(0, len(queries), 10)


#t
tasks = np.array([1, 2])

# %% [markdown]
# # Setting up functions

# %%
"""
get a random subset from list
"""
def get_subset(queries, nele=5):
    return np.random.choice(queries, nele)
    
"""
print formatted result with newlines
"""
def check_result(*args, **kwargs):
    print(str(check_output(format_input(*args, **kwargs)), 'utf-8'))
    
"""
************************************************************************
make a formatted inputs.
task: integer of the task number 
n_results: integer of number of result to display
file: the location of executable a1
*queries: queries used in program
************************************************************************
"""
def format_input(task, n_results, n_document=131563, *queries, file="./a1"):
    return [file, "-t", str(task), "-r", str(n_results), "-d", str(n_document), *queries]

"""
make a formatted run and return time it takes to execute
"""
def time_run(n_iter, *args, **kwargs):
    dts = 0
    for i in range(n_iter):
        t1 = time.time()
        print(format_input(*args, **kwargs)[:12])
        run(format_input(*args, **kwargs))
        dts += (time.time()-t1)
    return dts/n_iter*1000

"""
format output of time_run same as %timeit
"""
def formatted_time_run(n_iter, *args, **kwargs):
    print(args)
    print(kwargs)
    t = time_run(n_iter, *args, **kwargs)
    print("{} loops, {:.2f} ms per loop".format(n_iter, t))

# %% [markdown]
# # Trying with iterations

# %% [markdown]
# If any of the following printed result is 1. Means your program has bugs in it!

# %%
print("task1")
print(call(["./a1", "-t", "1", "-r", "10000", "algorithms", "are", "fun"]))
print(call(["./a1", "-t", "1", "-r", "0", "algorithms", "are", "fun"]))
print(call(["./a1", "-t", "1", "-r", "1000", "-d", "10", "algorithms"]))
print("task2")
print(call(["./a1", "-t", "2", "-r", "10000", "algorithms", "are", "fun"]))
print(call(["./a1", "-t", "2", "-r", "0", "algorithms", "are", "fun"]))
print(call(["./a1", "-t", "2", "-r", "1000", "-d", "10", "algorithms"]))
# Out:
# task1
# 0
# 0
# 0
# task2
# 0
# 0
# 0

# %% [markdown]
# Try some sample iterations

# %%
formatted_time_run(3, [1, 10, 3000], ["algorithms", "are", "fun"])
formatted_time_run(3, [2, 10, 3000], ["algorithms", "are", "fun"])
# %timeit run(["./a1", "-t", "1", "-r", "10", "-d", "3000", ["algorithms", "are", "fun"]])
# %timeit run(["./a1", "-t", "2", "-r", "10", "-d", "3000", ["algorithms", "are", "fun"]])
# Out:
# ([1, 10, 3000], ['algorithms', 'are', 'fun'])
# {}
# 3 loops, 93.92 ms per loop
# ([2, 10, 3000], ['algorithms', 'are', 'fun'])
# {}
# 3 loops, 87.23 ms per loop
# 60.2 ms ± 2.32 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 59.7 ms ± 2.04 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# # Try some plots
# These are for tests, the formal plot are below.
# check doc string of the parsed functions

# %% [markdown]
# ## Test with k (n_results)

# %% [markdown]
# ### Test with exponential distribution

# %%
subset1 = get_subset(queries, 2)
subset1  # This is the queries used to test program
# Out:
# array(['universe', 'april'], dtype='<U14')

# %% [markdown]
# #### Task 1
# n = 130
# m = 3000

# %%
n_document = 8000
n_iter = 3
# 1000, 2000, ...., 100000
lin_n_results = np.arange(0, 16000, 400)

# %%
subset1 = queries
y_expk_1 = []
for i in lin_n_results:
    y_expk_1.append(time_run(n_iter, 1, i, n_document, *subset1))
# Out:
# ['./a1', '-t', '1', '-r', '0', '-d', '8000', 'a', 'ada', 'age', 'air', 'alan']
# ['./a1', '-t', '1', '-r', '0', '-d', '8000', 'a', 'ada', 'age', 'air', 'alan']
# ['./a1', '-t', '1', '-r', '0', '-d', '8000', 'a', 'ada', 'age', 'air', 'alan']
# ['./a1', '-t', '1', '-r', '400', '-d', '8000', 'a', 'ada', 'age', 'air', 'alan']
# ['./a1', '-t', '1', '-r', '400', '-d', '8000', 'a', 'ada', 'age', 'air', 'alan']
# ['./a1', '-t', '1', '-r', '400', '-d', '8000', 'a', 'ada', 'age', 'air', 'alan']
# ['./a1', '-t', '1', '-r', '800', '-d', '8000', 'a', 'ada', 'age', 'air', 'alan']
# ['./a1', '-t', '1', '-r', '800', '-d', '8000', 'a', 'ada', 'age', 'air', 'alan']
# ['./a1', '-t', '1', '-r', '800', '-d', '8000', 'a', 'ada', 'age', 'air', 'alan']
# ['./a1', '-t', '1', '-r', '1200', '-d', '8000', 'a', 'ada', 'age', 'air', 'alan']
# ['./a1', '-t', '1', '-r', '1200', '-d', '8000', 'a', 'ada', 'age', 'air', 'alan']
# ['./a1', '-t', '1', '-r', '1200', '-d', '8000', 'a', 'ada', 'age', 'air', 'alan']
# ...

# %%
fig = plt.figure(figsize=[8,8])
plt.plot(lin_n_results, y_expk_1)
# fig.text(0.1, 0.5, "By Calvin Zhuoqun Huang",fontsize=50, color='gray',alpha=0.5)
plt.show()

# %%
fig = plt.figure(figsize=[8,8])
plt.plot(lin_n_results, y_expk_1)
plt.xscale("log")
# fig.text(0.1, 0.5, "By Calvin Zhuoqun Huang",fontsize=50, color='gray',alpha=0.5)
plt.show()

# %% [markdown]
# #### Task 2

# %%
y_expk_2 = []

for i in lin_n_results:
    y_expk_2.append(time_run(n_iter, 2, i, n_document, *subset1))
# Out:
# ['./a1', '-t', '2', '-r', '0', '-d', '8000', 'a', 'ada', 'age', 'air', 'alan']
# ['./a1', '-t', '2', '-r', '0', '-d', '8000', 'a', 'ada', 'age', 'air', 'alan']
# ['./a1', '-t', '2', '-r', '0', '-d', '8000', 'a', 'ada', 'age', 'air', 'alan']
# ['./a1', '-t', '2', '-r', '400', '-d', '8000', 'a', 'ada', 'age', 'air', 'alan']
# ['./a1', '-t', '2', '-r', '400', '-d', '8000', 'a', 'ada', 'age', 'air', 'alan']
# ['./a1', '-t', '2', '-r', '400', '-d', '8000', 'a', 'ada', 'age', 'air', 'alan']
# ['./a1', '-t', '2', '-r', '800', '-d', '8000', 'a', 'ada', 'age', 'air', 'alan']
# ['./a1', '-t', '2', '-r', '800', '-d', '8000', 'a', 'ada', 'age', 'air', 'alan']
# ['./a1', '-t', '2', '-r', '800', '-d', '8000', 'a', 'ada', 'age', 'air', 'alan']
# ['./a1', '-t', '2', '-r', '1200', '-d', '8000', 'a', 'ada', 'age', 'air', 'alan']
# ['./a1', '-t', '2', '-r', '1200', '-d', '8000', 'a', 'ada', 'age', 'air', 'alan']
# ['./a1', '-t', '2', '-r', '1200', '-d', '8000', 'a', 'ada', 'age', 'air', 'alan']
# ...

# %%
fig = plt.figure(figsize=[8,8])
plt.plot(lin_n_results, y_expk_2)
# fig.text(0.1, 0.5, "By Calvin Zhuoqun Huang",
#          fontsize=50, color='gray',alpha=0.5)
plt.show()

# %%
fig = plt.figure(figsize=[8,8])
plt.plot(lin_n_results, y_expk_2)
plt.xscale("log")
plt.show()

# %% [markdown]
# #### together

# %%
fig = plt.figure(figsize=[8,8])
plt.plot(lin_n_results, y_expk_1, c='r')
plt.plot(lin_n_results, y_expk_2, c='b')
plt.legend(["task1", "task2"])
plt.ylabel("run time(ms)")
plt.xlabel("k: n_result")
plt.title("m:{} n:/data/*.txt p:{}".format(n_document, "18041"))

save = "ktime"
plt.savefig(save)
plt.show()

# %%
fig = plt.figure(figsize=[8,8])
plt.plot(lin_n_results, y_expk_1, c='r')
plt.plot(lin_n_results, y_expk_2, c='b')
plt.xscale("log")
plt.legend(["task1", "task2"])
plt.show()

# %%
fig = plt.figure(figsize=[8,8])
plt.scatter(lin_n_results, y_expk_1, c='r')
plt.scatter(lin_n_results, y_expk_2, c='b')
# plt.xscale("log")
plt.legend(["task1", "task2"])
plt.show()

# %% [markdown]
# ## test m: n_documents

# %% [markdown]
# ### task1

# %%
subset1 = queries

n_result = 100

x_m_1 = [i for i in np.arange(0, 120000, 10000)]
y_m_1 = []

for i in x_m_1:
    y_m_1.append(time_run(n_iter, 1, n_result, i, *subset1))

# %%
fig = plt.figure(figsize=[8,8])
plt.plot(x_m_1, y_m_1)
# fig.text(0.1, 0.5, "By Calvin Zhuoqun Huang",fontsize=50, color='gray',alpha=0.5)
plt.show()

# %%
fig = plt.figure(figsize=[8,8])
plt.plot(x_m_1, y_m_1)
plt.xscale("log")
# fig.text(0.1, 0.5, "By Calvin Zhuoqun Huang",fontsize=50, color='gray',alpha=0.5)
plt.show()

# %% [markdown]
# ### Task 2

# %%
y_m_2 = []
n_result = 100

for i in x_m_1:
    y_m_2.append(time_run(n_iter, 2, n_result, i, *subset1))

# %%
fig = plt.figure(figsize=[8,8])
plt.plot(x_m_1, y_m_2)
# fig.text(0.1, 0.5, "By Calvin Zhuoqun Huang",
#          fontsize=50, color='gray',alpha=0.5)
plt.show()

# %%
fig = plt.figure(figsize=[8,8])
plt.plot(x_m_1, y_m_2)
plt.xscale("log")
plt.show()

# %% [markdown]
# ### together

# %%
fig = plt.figure(figsize=[8,8])
plt.plot(x_m_1, y_m_1, c='r')
plt.plot(x_m_1, y_m_2, c='b')
plt.xscale("log")
plt.legend(["task1", "task2"])
plt.xlabel("m: n_documents")
plt.ylabel("run time(ms)")
plt.title("k:{}, n:{} p:{} asymptomatic plot of k".format(n_result, "all *.txt in /data", "18041"))
plt.legend(["task1", "task2"])

save = "mlogtime"
plt.savefig(save)
plt.show()

# %%
fig = plt.figure(figsize=[8,8])
plt.plot(x_m_1, y_m_1, c='r')
plt.plot(x_m_1, y_m_2, c='b')
# plt.xscale("log")
plt.xlabel("m: n_documents")
plt.ylabel("run time(ms)")
plt.title("k:{}, n:{} p:{} asymptomatic plot of m".format(n_result, "all *.txt in /data", "18041"))
plt.legend(["task1", "task2"])

save = "mtime"
plt.savefig(save)
plt.show()

# %%
ratio = [y_m_2[i]/y_m_1[i] for i in range(len(y_m_1))]

fig = plt.figure(figsize=[8,8])
plt.plot(x_m_1, ratio)
plt.xlabel("m: n_documents")
plt.ylabel("ratio: task1's time/ task2's time")
plt.title("k:{}, n:{} p:{} ratio plot of task1&2".format(n_result, "all *.txt in /data", "18041"))

save = "mtimeratio"
plt.savefig(save)
plt.show()

# %% [markdown]
# ## p: length of list

# %% [markdown]
# ### task1

# %%
subset1 = queries


n_document = 4000
n_query = 16

step = 50
query_txt = ["modify_{}".format(i) for i in range(1, n_query+1)]

x_n_1 = [i for i in np.arange(0, n_document, step)]

n_result = 20

import random

# %%
y_n_1 = []
count = 0
for i in range(0, int(n_document/step)):
    count = 0
    for j in range(0, step):
        for k in range(1, n_query+1):
            f = open('data/modify_{}.txt'.format(k),'a')
            f.write("{} {}\n".format(int(i*step+j), random.uniform(0.0, 1.0/float(n_query))))
            f.close()
    
    y_n_1.append(time_run(n_iter, 1, n_result, n_document, *query_txt))
# Out:
# ['./a1', '-t', '1', '-r', '20', '-d', '4000', 'modify_1', 'modify_2', 'modify_3', 'modify_4', 'modify_5']
# ['./a1', '-t', '1', '-r', '20', '-d', '4000', 'modify_1', 'modify_2', 'modify_3', 'modify_4', 'modify_5']
# ['./a1', '-t', '1', '-r', '20', '-d', '4000', 'modify_1', 'modify_2', 'modify_3', 'modify_4', 'modify_5']
# ['./a1', '-t', '1', '-r', '20', '-d', '4000', 'modify_1', 'modify_2', 'modify_3', 'modify_4', 'modify_5']
# ['./a1', '-t', '1', '-r', '20', '-d', '4000', 'modify_1', 'modify_2', 'modify_3', 'modify_4', 'modify_5']
# ['./a1', '-t', '1', '-r', '20', '-d', '4000', 'modify_1', 'modify_2', 'modify_3', 'modify_4', 'modify_5']
# ['./a1', '-t', '1', '-r', '20', '-d', '4000', 'modify_1', 'modify_2', 'modify_3', 'modify_4', 'modify_5']
# ['./a1', '-t', '1', '-r', '20', '-d', '4000', 'modify_1', 'modify_2', 'modify_3', 'modify_4', 'modify_5']
# ['./a1', '-t', '1', '-r', '20', '-d', '4000', 'modify_1', 'modify_2', 'modify_3', 'modify_4', 'modify_5']
# ...

# %%
fig = plt.figure(figsize=[8,8])
plt.plot(x_n_1, y_n_1)
# fig.text(0.1, 0.5, "By Calvin Zhuoqun Huang",
#          fontsize=50, color='gray',alpha=0.5)
plt.show()

# %%
fig = plt.figure(figsize=[8,8])
plt.plot(x_n_1, y_n_1)
plt.xscale("log")
plt.show()

# %% [markdown]
# ### delete data txt

# %%
for i in range(1, n_query+1):
    os.remove('data/modify_{}.txt'.format(i))

# %% [markdown]
# ### task2

# %%
subset1 = queries


n_document = 4000
n_query = 16

step = 50
query_txt = ["modify_{}".format(i) for i in range(1, n_query+1)]

x_n_2 = [i for i in np.arange(0, n_document, step)]

n_result = 20

# %%
count = 0
for i in range(0, int(n_document/step)):
    count = 0
    for j in range(0, step):
        for k in range(1, n_query+1):
            f = open('data/modify_{}.txt'.format(k),'a')
            f.write("{} {}\n".format(int(i*step+j), random.uniform(0.0, 1.0/float(n_query))))
            f.close()
    
    y_n_2.append(time_run(n_iter, 2, n_result, n_document, *query_txt))
# Out:
# ['./a1', '-t', '2', '-r', '20', '-d', '4000', 'modify_1', 'modify_2', 'modify_3', 'modify_4', 'modify_5']
# ['./a1', '-t', '2', '-r', '20', '-d', '4000', 'modify_1', 'modify_2', 'modify_3', 'modify_4', 'modify_5']
# ['./a1', '-t', '2', '-r', '20', '-d', '4000', 'modify_1', 'modify_2', 'modify_3', 'modify_4', 'modify_5']
# ['./a1', '-t', '2', '-r', '20', '-d', '4000', 'modify_1', 'modify_2', 'modify_3', 'modify_4', 'modify_5']
# ['./a1', '-t', '2', '-r', '20', '-d', '4000', 'modify_1', 'modify_2', 'modify_3', 'modify_4', 'modify_5']
# ['./a1', '-t', '2', '-r', '20', '-d', '4000', 'modify_1', 'modify_2', 'modify_3', 'modify_4', 'modify_5']
# ['./a1', '-t', '2', '-r', '20', '-d', '4000', 'modify_1', 'modify_2', 'modify_3', 'modify_4', 'modify_5']
# ['./a1', '-t', '2', '-r', '20', '-d', '4000', 'modify_1', 'modify_2', 'modify_3', 'modify_4', 'modify_5']
# ['./a1', '-t', '2', '-r', '20', '-d', '4000', 'modify_1', 'modify_2', 'modify_3', 'modify_4', 'modify_5']
# ...

# %%
fig = plt.figure(figsize=[8,8])
plt.plot(x_n_2, y_n_2)
# fig.text(0.1, 0.5, "By Calvin Zhuoqun Huang",
#          fontsize=50, color='gray',alpha=0.5)
plt.show()

# %%
fig = plt.figure(figsize=[8,8])
plt.plot(x_n_2, y_n_2)
plt.xscale("log")
plt.show()

# %% [markdown]
# ### together

# %%
fig = plt.figure(figsize=[8,8])
plt.plot(x_n_1, y_n_1, c='r')
plt.plot(x_n_2, y_n_2, c='b')
plt.legend(["task1", "task2"])
plt.xscale("log")
plt.xlabel("p:average of length of doculists[...]")
plt.ylabel("runtime(ms)")
plt.title("k:{}, n:{} m:{} asymptomatic plot of p".format(n_result, "all *.txt in /data", n_document))

save = "ptime"
plt.savefig(save)
plt.show()

# %%
ratio = [y_n_2[i]/y_n_1[i] for i in range(len(y_n_1))]
fig = plt.figure(figsize=[8,8])
plt.plot(x_n_1, ratio)
plt.xlabel("p:average of length of doculists[...]")
plt.ylabel("ratio: task1's time/ task2's time")
plt.title("k:{}, n:{} m:{} ratio plot of task1&2".format(n_result, "all *.txt in /data", n_document))

save = "ptimeratio"
plt.savefig(save)
plt.show()

# %% [markdown]
# ### delete data txt

# %%
for i in range(1, n_query+1):
    os.remove('data/modify_{}.txt'.format(i))

# %% [markdown]
# ## n: n_query

# %% [markdown]
# ### generate txt

# %%
n_query = 2000
n_document = 30 # p=30
n_result = 5

step = 80

query_txt = ["modify_{}.txt".format(i) for i in range(0, n_query)]

x_n = [step*i for i in range(1, int(n_query/step))]

# %%
# generating file careful to use
for i in range(0, len(query_txt)):
    for j in range(0, n_document):
        f = open('data/modify_{}.txt'.format(i),'a')
        f.write("{} {}\n".format(j, random.uniform(0.0, 0.3)))
        f.close()

# %% [markdown]
# ### task 1

# %%
y_n_query_1 = []

for i in range(1, int(n_query/step)):
    y_n_query_1.append(time_run(n_iter, 1, n_result, n_document, *(query_txt[:int(i*step)])))
# Out:
# ['./a1', '-t', '1', '-r', '5', '-d', '30', 'modify_0.txt', 'modify_1.txt', 'modify_2.txt', 'modify_3.txt', 'modify_4.txt']
# ['./a1', '-t', '1', '-r', '5', '-d', '30', 'modify_0.txt', 'modify_1.txt', 'modify_2.txt', 'modify_3.txt', 'modify_4.txt']
# ['./a1', '-t', '1', '-r', '5', '-d', '30', 'modify_0.txt', 'modify_1.txt', 'modify_2.txt', 'modify_3.txt', 'modify_4.txt']
# ['./a1', '-t', '1', '-r', '5', '-d', '30', 'modify_0.txt', 'modify_1.txt', 'modify_2.txt', 'modify_3.txt', 'modify_4.txt']
# ['./a1', '-t', '1', '-r', '5', '-d', '30', 'modify_0.txt', 'modify_1.txt', 'modify_2.txt', 'modify_3.txt', 'modify_4.txt']
# ['./a1', '-t', '1', '-r', '5', '-d', '30', 'modify_0.txt', 'modify_1.txt', 'modify_2.txt', 'modify_3.txt', 'modify_4.txt']
# ['./a1', '-t', '1', '-r', '5', '-d', '30', 'modify_0.txt', 'modify_1.txt', 'modify_2.txt', 'modify_3.txt', 'modify_4.txt']
# ['./a1', '-t', '1', '-r', '5', '-d', '30', 'modify_0.txt', 'modify_1.txt', 'modify_2.txt', 'modify_3.txt', 'modify_4.txt']
# ...

# %%
fig = plt.figure(figsize=[8,8])
plt.plot(x_n, y_n_query_1)
plt.show()

# %%
fig = plt.figure(figsize=[8,8])
plt.plot(x_n, y_n_query_1)
plt.xscale("log")
plt.show()

# %%
# exp_x_m_1 = np.concatenate([[0], np.logspace(0, int(np.log2(n_document)), base=2)], axis=0)
# for i in range(len(exp_x_m_1)):
#     exp_x_m_1[i] = int(exp_x_m_1[i])

# %%
# exp_y_n_1 = []
# for i in exp_x_m_1[i]:    
#     exp_y_n_1.append(time_run(n_iter, 1, n_result, n_document, *query_txt))

# %% [markdown]
# ### task 2

# %%
y_n_query_2 = []

for i in range(1, int(n_query/step)):
    
    y_n_query_2.append(time_run(n_iter, 2, n_result, n_document, *(query_txt[:int(i*step)])))
# Out:
# ['./a1', '-t', '2', '-r', '5', '-d', '30', 'modify_0.txt', 'modify_1.txt', 'modify_2.txt', 'modify_3.txt', 'modify_4.txt']
# ['./a1', '-t', '2', '-r', '5', '-d', '30', 'modify_0.txt', 'modify_1.txt', 'modify_2.txt', 'modify_3.txt', 'modify_4.txt']
# ['./a1', '-t', '2', '-r', '5', '-d', '30', 'modify_0.txt', 'modify_1.txt', 'modify_2.txt', 'modify_3.txt', 'modify_4.txt']
# ['./a1', '-t', '2', '-r', '5', '-d', '30', 'modify_0.txt', 'modify_1.txt', 'modify_2.txt', 'modify_3.txt', 'modify_4.txt']
# ['./a1', '-t', '2', '-r', '5', '-d', '30', 'modify_0.txt', 'modify_1.txt', 'modify_2.txt', 'modify_3.txt', 'modify_4.txt']
# ['./a1', '-t', '2', '-r', '5', '-d', '30', 'modify_0.txt', 'modify_1.txt', 'modify_2.txt', 'modify_3.txt', 'modify_4.txt']
# ['./a1', '-t', '2', '-r', '5', '-d', '30', 'modify_0.txt', 'modify_1.txt', 'modify_2.txt', 'modify_3.txt', 'modify_4.txt']
# ['./a1', '-t', '2', '-r', '5', '-d', '30', 'modify_0.txt', 'modify_1.txt', 'modify_2.txt', 'modify_3.txt', 'modify_4.txt']
# ...

# %%
fig = plt.figure(figsize=[8,8])
plt.plot(x_n, y_n_query_2)
plt.show()

# %%
fig = plt.figure(figsize=[8,8])
plt.plot(x_n, y_n_query_2)
plt.xscale("log")
plt.show()

# %% [markdown]
# ### together

# %%
fig = plt.figure(figsize=[8,8])
plt.plot(x_n, y_n_query_1, c='r')
plt.plot(x_n, y_n_query_2, c='b')
plt.legend(["task1", "task2"])
plt.xlabel("n: n_query")
plt.ylabel("runtime(ms)")
plt.title("k:{}, p:{} m:{} asymptomatic plot of n".format(n_result, n_document, n_document))

save = "nlogntime"
plt.savefig(save)
plt.show()

# %%
ratio = [y_n_query_2[i]/y_n_query_1[i] for i in range(len(y_n_query_1))]

fig = plt.figure(figsize=[8,8])
plt.plot(x_n, ratio)

plt.xlabel("n: n_query")
plt.ylabel("ratio: task1's time/ task2's time")
plt.title("k:{}, p:{} m:{} ratio plot of task1&2".format(n_result, n_document, n_document))

save = "nlogntimeratio"
plt.savefig(save)
plt.show()

# %% [markdown]
# ### delete data txt

# %%
# for i in range(0, n_query):
#     os.remove('data/modify_{}.txt'.format(i))
# careful to use cause recreate is time consuming
